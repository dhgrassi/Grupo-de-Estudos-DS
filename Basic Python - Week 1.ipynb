# %%
#Exercício 1.1
z = False+True
print (z, type (z))
# Out:
# 1 <class 'int'>

# %%
#Exercício 1.2

ano = int(input('Digite um valor entre 0 e 3000: '))
if ano%4 == 0:
     y = 'Pode ser um ano bissexto'
else:
    y = 'Definitivamente não é um ano bissexto'

print (y)
# Out:
# Digite um valor entre 0 e 3000: 50
# Definitivamente não é um ano bissexto

# %%
#Exercício 1.3
#PEDIR AJUDA
valores = ['três', 56, 342, 12.4e-5, 4+3j, ('A', 1, 50.1), -0.19e4, 1000, 960, -406]
numeros = []
for i in valores:
    if (type(i) == float or type(i) == int):
        numeros.append(i)
        
print(numeros)
# Out:
# [56, 342, 0.000124, -1900.0, 1000, 960, -406]

# %%
#Exercício 1.4
#Dada a lista valores abaixo, crie uma nova lista chamada numeros contendo apenas elementos float ou int.
#Note que essa nova lista pode ter menos elementos do que a lista existente.
#Ao final exiba a nova lista numeros
#Dica: Percorra a lista com uma estrutura de repetição e utilize type() para retornar o tipo e compare com o desejado. Exemplo:

#type(3) == int
#Retorna True

# %%
valores = ['três', 56, 342, 12.4e-5, 4+3j, ('A', 1, 50.1), -0.19e4, 1000, 960, -406]

# %%
numeros = []
for i in valores:
    if (type(i) == float or type(i) == int):
        numeros.append(i)
        
print(numeros)
# Out:
# [56, 342, 0.000124, -1900.0, 1000, 960, -406]

# %%
#Exercício 1.5
#Considere a lista linguagens declarada abaixo.
#Utilizando fatiamento, imprima o subconjunto de elementos entre o segundo e o quarto elemento (inclusive)
#Gere uma nova lista chamada maiores4 contendo os elementos da lista linguagens que possuam quatro caracteres ou mais, utilizando a função len().
#Gere uma nova lista chamada j_ou_c contendo os elementos da lista linguagens que começam com a letra 'j' ou com a letra 'c'.

linguagens = ['python', 'java', 'c++', 'javascript', 'c#', 'go', 'r', 'cobol', 'ruby', 'lisp']
print(linguagens[1:4])
# Out:
# ['java', 'c++', 'javascript']

# %%
maiores4 = []
for i in linguagens:
    if(len(i)>=4):
        maiores4.append(i)
print(maiores4)
# Out:
# ['python', 'java', 'javascript', 'cobol', 'ruby', 'lisp']

# %%
j_ou_c = []
for elemento in linguagens:
    if  (elemento[0]=='j'):
        j_ou_c.append(elemento)
    if  (elemento[0]=='c'):
        j_ou_c.append(elemento)
print(j_ou_c)
# Out:
# ['java', 'c++', 'javascript', 'c#', 'cobol']

# %%
(linguagens[1][0]=='j')
# Out:
# True

# %%
#Exercício 1.6
nomes = "ana,fábio,cristina,ana,fábio,ubiratã,ana"
nomes.split(,)
# Out:
#   File "<ipython-input-4-04bddfa03415>", line 3
#     nomes.split(,)
#                 ^
# SyntaxError: invalid syntax

# %%
def conta_palavras(frase):
    pals = frase.split(',')
    freq = {}
    
    for p in pals:
        if p not in freq:
            freq[p] = 1
        else:
            freq[p] += 1
            
    return freq

nomes = "ana,fábio,cristina,ana,fábio,ubiratã,ana"
freq = conta_palavras(nomes)
print(freq)
# Out:
# {'ana': 3, 'fábio': 2, 'cristina': 1, 'ubiratã': 1}

# %%
#Exercício 1.7
produtos = [('soja', [170.1, 183.0, 175.0]),
            ('algodao', [143.4]),
            ('cacau', [199, 185.1]),
            ('café', [880, 750.9, 795.1, 900])]

from math import fsum
from random import randint

preco_medio = []
for p in produtos:
    media = fsum(p[1])/len(p[1])
    preco_medio.append(media)

sorteio = randint(0,len(produtos)-1)
print(produtos[sorteio][0], "preço médio=", preco_medio[sorteio])
# Out:
# soja preço médio= 176.03333333333333

# %%
#Exercício 1.7
produtos = [('soja', [170.1, 183.0, 175.0]),
            ('algodao', [143.4]),
            ('cacau', [199, 185.1]),
            ('café', [880, 750.9, 795.1, 900])]
for p in produtos:
    print (p[1])
len(produtos)
# Out:
# [170.1, 183.0, 175.0]
# [143.4]
# [199, 185.1]
# [880, 750.9, 795.1, 900]
# 4

# %%
#Avaliação - Questão 1
lv = [('BRA', 'DFD-2992', 12, 2021, 999.0),
      ('ARG', '1112992', 1, 2022, 899.0),
      ('EUA', 'AB3DA000', 11, 2021, 1023.0),
      ('BRA', 'GCG-1112', 9, 2021, 900.0),
      ('ESP', 'DFD-2992', 11, 2021, 899.0),
      ('URU', 'AEC423', 3, 2023, 699.0),
      ('PAR', 'DFD-2992', 2, 2025, 1099.0),
      ('ARL', 'X123111Z', 10, 2021, 954.0),
      ('URU', 'BAC203', 2, 2025, 1011.0),
      ('ARG', '3112323', 10, 2021, 1250.0),
      ('URU', 'ABC123', 12, 2024, 1001.5),
      ('BRA', 'AAB-2992', 8, 2021, 1050.9),
      ('BRA', 'EFE-2992', 8, 2022, 1170.1),
      ('VEN', 'GAC292', 4, 2023, 1000.6),
      ('PER', '2992DDE', 9, 2021, 989.9)]
precos = []
for i in lv:
    precos.append(i[4])
print(precos)
# Out:
# [999.0, 899.0, 1023.0, 900.0, 899.0, 699.0, 1099.0, 954.0, 1011.0, 1250.0, 1001.5, 1050.9, 1170.1, 1000.6, 989.9]

# %%
média = sum(precos)/len(precos)
print(média)
# Out:
# 996.4

# %%
#Avaliação Questão 2
vencidos=[]
for i in lv:
    if(i[2]<=12 and i[3]<=2021):
        vencidos.append(i[0])
print(vencidos)
# Out:
# ['BRA', 'EUA', 'BRA', 'ESP', 'ARL', 'ARG', 'BRA', 'PER']

# %%
def conta_vencidos(vencidos):
    pals = vencidos.split(',')
    freq = {}
    
    for p in pals:
        if p not in freq:
            freq[p] = 1
        else:
            freq[p] += 1
            
    return freq

vencidos = "BRA,EUA,BRA,ESP,ARL,ARG,BRA,PER"
freq = conta_vencidos(vencidos)
print(freq)
# Out:
# {'BRA': 3, 'EUA': 1, 'ESP': 1, 'ARL': 1, 'ARG': 1, 'PER': 1}

# %%
#Avaliação Questão 3
for i in lv:
    print(i[2],'/',i[3])
# Out:
# 12 / 2021
# 1 / 2022
# 11 / 2021
# 9 / 2021
# 11 / 2021
# 3 / 2023
# 2 / 2025
# 10 / 2021
# 2 / 2025
# 10 / 2021
# 12 / 2024
# 8 / 2021
# 8 / 2022
# 4 / 2023
# 9 / 2021

# %%
datas = []
for i in lv:
    datas.append(i[2]),datas.append(i[3])
print(datas)
# Out:
# [12, 2021, 1, 2022, 11, 2021, 9, 2021, 11, 2021, 3, 2023, 2, 2025, 10, 2021, 2, 2025, 10, 2021, 12, 2024, 8, 2021, 8, 2022, 4, 2023, 9, 2021]

# %%
datas1 = []
for i in lv:
        datas1.append(i[2:4])
print(datas1)
# Out:
# [(12, 2021), (1, 2022), (11, 2021), (9, 2021), (11, 2021), (3, 2023), (2, 2025), (10, 2021), (2, 2025), (10, 2021), (12, 2024), (8, 2021), (8, 2022), (4, 2023), (9, 2021)]

# %%
seq = 'adeakziomltmd'

seq_ordenada_lista = sorted(seq) # ordena a sequência de caracteres e salva em uma nova variavel. 
                           # A saida do método é uma lista
                           # A sequência original não é afetada
print('Sequencia ordenanda: ', seq_ordenada_lista) 
print('Sequencia original: ', seq)
print(type(seq),type(seq_ordenada_lista))

# Convertendo uma lista em uma sequência de caracteres (string)
seq_ordenada ='*'.join(seq_ordenada_lista)  # o comando join contatena elementos em uma string utilizando um separador.
                                           # Neste caso o separador nao é fornecido, logo os caracteres ficam "colados".
                                           # Rode o comando com '*'.join(seq_ordenada_lista) e veja o resultado
print("Sequencia ordenada no formato string: ",seq_ordenada)

seq_max = max(seq)  # retorna o maior elemento da sequência
print('Maior elemento: ', seq_max)
seq_min = min(seq)  # retorna o menor elemento da sequência
print('Menor elemento: ', seq_min)
# Out:
# Sequencia ordenanda:  ['a', 'a', 'd', 'd', 'e', 'i', 'k', 'l', 'm', 'm', 'o', 't', 'z']
# Sequencia original:  adeakziomltmd
# <class 'str'> <class 'list'>
# Sequencia ordenada no formato string:  a*a*d*d*e*i*k*l*m*m*o*t*z
# Maior elemento:  z
# Menor elemento:  a

# %%
#Exercício 1.8
import pandas as pd
dados = pd.read_csv (r'C:\Users\d016734\Downloads\WorldCups.csv')
df = pd.DataFrame(dados, columns= ['Year'])
print (df)
# Out:
#     Year
# 0   1930
# 1   1934
# 2   1938
# 3   1950
# 4   1954
# 5   1958
# 6   1962
# 7   1966
# 8   1970
# 9   1974
# 10  1978
# 11  1982
# 12  1986
# 13  1990
# 14  1994
# 15  1998
# 16  2002
# 17  2006
# 18  2010
# 19  2014

# %%
dados = pd.read_csv (r'C:\Users\d016734\Downloads\WorldCups.csv')
dados
# Out:
#     Year       Country      Winner       RunnersUp        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
dados.head()
# Out:
#    Year      Country      Winner       RunnersUp    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed  Attendance
# 0           70              13             18      590549
# 1           70              16             17      363000
# 2           84              15             18      375700
# 3           88              13             22     1045246
# 4          140              16             26      768607

# %%
dados.dtypes
# Out:
# Year               int64
# Country           object
# Winner            object
# RunnersUp         object
# Third             object
# Fourth            object
# GoalsScored        int64
# QualifiedTeams     int64
# MatchesPlayed      int64
# Attendance         int64
# dtype: object

# %%
dados.shape
# Out:
# (20, 10)

# %%
dados
# Out:
#     Year       Country      Winner       RunnersUp        Third  GoalsScored  \
# 0   1930       Uruguay     Uruguay       Argentina          USA           70
# 1   1934         Italy       Italy  Czechoslovakia      Germany           70
# 2   1938        France       Italy         Hungary       Brazil           84
# 3   1950        Brazil     Uruguay          Brazil       Sweden           88
# 4   1954   Switzerland  Germany FR         Hungary      Austria          140
# 5   1958        Sweden      Brazil          Sweden       France          126
# 6   1962         Chile      Brazil  Czechoslovakia        Chile           89
# 7   1966       England     England      Germany FR     Portugal           89
# 8   1970        Mexico      Brazil           Italy   Germany FR           95
# 9   1974       Germany  Germany FR     Netherlands       Poland           97
# 10  1978     Argentina   Argentina     Netherlands       Brazil          102
# ...

# %%
dados.drop('QualifiedTeams', axis=1)
# Out:
#     Year       Country      Winner       RunnersUp        Third  GoalsScored  \
# 0   1930       Uruguay     Uruguay       Argentina          USA           70
# 1   1934         Italy       Italy  Czechoslovakia      Germany           70
# 2   1938        France       Italy         Hungary       Brazil           84
# 3   1950        Brazil     Uruguay          Brazil       Sweden           88
# 4   1954   Switzerland  Germany FR         Hungary      Austria          140
# 5   1958        Sweden      Brazil          Sweden       France          126
# 6   1962         Chile      Brazil  Czechoslovakia        Chile           89
# 7   1966       England     England      Germany FR     Portugal           89
# 8   1970        Mexico      Brazil           Italy   Germany FR           95
# 9   1974       Germany  Germany FR     Netherlands       Poland           97
# 10  1978     Argentina   Argentina     Netherlands       Brazil          102
# ...

# %%
dados.set_index('Year', inplace=True)
dados
# Out:
#            Country      Winner       RunnersUp        Third  GoalsScored  \
# Year
# 1930       Uruguay     Uruguay       Argentina          USA           70
# 1934         Italy       Italy  Czechoslovakia      Germany           70
# 1938        France       Italy         Hungary       Brazil           84
# 1950        Brazil     Uruguay          Brazil       Sweden           88
# 1954   Switzerland  Germany FR         Hungary      Austria          140
# 1958        Sweden      Brazil          Sweden       France          126
# 1962         Chile      Brazil  Czechoslovakia        Chile           89
# 1966       England     England      Germany FR     Portugal           89
# 1970        Mexico      Brazil           Italy   Germany FR           95
# 1974       Germany  Germany FR     Netherlands       Poland           97
# 1978     Argentina   Argentina     Netherlands       Brazil          102
# 1982         Spain       Italy      Germany FR       Poland          146
# ...

# %%
dados.iloc[:,1]
# Out:
# Year
# 1930       Uruguay
# 1934         Italy
# 1938         Italy
# 1950       Uruguay
# 1954    Germany FR
# 1958        Brazil
# 1962        Brazil
# 1966       England
# 1970        Brazil
# 1974    Germany FR
# 1978     Argentina
# 1982         Italy
# 1986     Argentina
# 1990    Germany FR
# 1994        Brazil
# 1998        France
# 2002        Brazil
# 2006         Italy
# 2010         Spain
# 2014       Germany
# Name: Winner, dtype: object

# %%
dados
# Out:
#            Country      Winner       RunnersUp        Third  GoalsScored  \
# Year
# 1930       Uruguay     Uruguay       Argentina          USA           70
# 1934         Italy       Italy  Czechoslovakia      Germany           70
# 1938        France       Italy         Hungary       Brazil           84
# 1950        Brazil     Uruguay          Brazil       Sweden           88
# 1954   Switzerland  Germany FR         Hungary      Austria          140
# 1958        Sweden      Brazil          Sweden       France          126
# 1962         Chile      Brazil  Czechoslovakia        Chile           89
# 1966       England     England      Germany FR     Portugal           89
# 1970        Mexico      Brazil           Italy   Germany FR           95
# 1974       Germany  Germany FR     Netherlands       Poland           97
# 1978     Argentina   Argentina     Netherlands       Brazil          102
# 1982         Spain       Italy      Germany FR       Poland          146
# ...

# %%
dados.iloc[4:12,1:2]
# Out:
#           Winner
# Year
# 1954  Germany FR
# 1958      Brazil
# 1962      Brazil
# 1966     England
# 1970      Brazil
# 1974  Germany FR
# 1978   Argentina
# 1982       Italy

# %%
copa = pd.read_csv (r'C:\Users\d016734\Downloads\WorldCupMatches.csv')
copa
# Out:
#      Year              Datetime           Stage             Stadium  \
# 0    1930  13 Jul 1930 - 15:00          Group 1             Pocitos
# 1    1930  13 Jul 1930 - 15:00          Group 4      Parque Central
# 2    1930  14 Jul 1930 - 12:45          Group 2      Parque Central
# 3    1930  14 Jul 1930 - 14:50          Group 3             Pocitos
# 4    1930  15 Jul 1930 - 16:00          Group 1      Parque Central
# ..    ...                   ...             ...                 ...
# 831  2014  05 Jul 2014 - 13:00   Quarter-finals    Estadio Nacional
# 832  2014  29 Jun 2014 - 13:00      Round of 16    Estadio Castelao
# 833  2014  29 Jun 2014 - 17:00      Round of 16    Arena Pernambuco
# 834  2014  01 Jul 2014 - 13:00      Round of 16  Arena de Sao Paulo
# 835  2014  01 Jul 2014 - 17:00      Round of 16    Arena Fonte Nova
#
#             City HomeTeamName  HomeTeamGoals  AwayTeamGoals AwayTeamName  \
# 0    Montevideo        France              4              1       Mexico
# ...

# %%
copa.shape
# Out:
# (836, 20)

# %%
copa.dtypes
# Out:
# Year                   int64
# Datetime              object
# Stage                 object
# Stadium               object
# City                  object
# HomeTeamName          object
# HomeTeamGoals          int64
# AwayTeamGoals          int64
# AwayTeamName          object
# WinConditions         object
# Attendance           float64
# HalfTimeHomeGoals      int64
# HalfTimeAwayGoals      int64
# Referee               object
# Assistant1            object
# Assistant2            object
# RoundID                int64
# MatchID                int64
# HomeTeamInitials      object
# AwayTeamInitials      object
# dtype: object

# %%
copa['TotalGoals'] = 
copa
# Out:
#   File "<ipython-input-238-4141021667fc>", line 1
#     copa['TotalGoals'] =
#                          ^
# SyntaxError: invalid syntax

# %%
copa.iloc[0:836,6:8]
# Out:
#      HomeTeamGoals  AwayTeamGoals
# 0                4              1
# 1                3              0
# 2                2              1
# 3                3              1
# 4                1              0
# ..             ...            ...
# 831              1              0
# 832              2              1
# 833              1              1
# 834              1              0
# 835              2              1
#
# [836 rows x 2 columns]

# %%
#Respostas Avaliação:
#1 - 996,4 (a)
#2 - 3, 1, 4 (a)
#3 - 6 (c)
#4 - 20 colunas, 8 numéricas (c)
#5 - 4 jogos, 1954 (e)
